# %%
from transformers import pipeline

# %%
classifier = pipeline("sentiment-analysis")
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision af0f99b (https://huggingface.co/distilbert/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.

# %%
classifier("The death of summer Arctic ice our Earth cooler is now just a few years away if not sooner triggerin...")
# Out:
# [{'label': 'NEGATIVE', 'score': 0.9994472861289978}]

# %%
print(pipeline('sentiment-analysis')('we love you'))
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision af0f99b (https://huggingface.co/distilbert/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# [{'label': 'POSITIVE', 'score': 0.9998704195022583}]

# %%
import pandas as pd
Tweets = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Sentiment analysis/Climate_twitter.csv')
for i in range(len(Tweets)):
  print(classifier(Tweets['text'][i]))
# Out:
# [{'label': 'NEGATIVE', 'score': 0.9978460073471069}]
# [{'label': 'POSITIVE', 'score': 0.9992092251777649}]
# [{'label': 'POSITIVE', 'score': 0.9518690705299377}]
# [{'label': 'POSITIVE', 'score': 0.9020661115646362}]
# [{'label': 'POSITIVE', 'score': 0.8970346450805664}]
# [{'label': 'NEGATIVE', 'score': 0.9041115045547485}]
# [{'label': 'NEGATIVE', 'score': 0.9832467436790466}]
# [{'label': 'NEGATIVE', 'score': 0.8719581365585327}]
# [{'label': 'POSITIVE', 'score': 0.9393634796142578}]
# [{'label': 'NEGATIVE', 'score': 0.9979251623153687}]
# [{'label': 'NEGATIVE', 'score': 0.9959836006164551}]
# [{'label': 'NEGATIVE', 'score': 0.9940349459648132}]
# [{'label': 'NEGATIVE', 'score': 0.699179470539093}]
# [{'label': 'POSITIVE', 'score': 0.9577770829200745}]
# [{'label': 'POSITIVE', 'score': 0.5738173127174377}]
# [{'label': 'NEGATIVE', 'score': 0.9954872727394104}]
# [{'label': 'POSITIVE', 'score': 0.9963477253913879}]
# [{'label': 'NEGATIVE', 'score': 0.9841933846473694}]
# ...
